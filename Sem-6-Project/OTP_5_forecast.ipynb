# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# !pip install yfinance
import yfinance as yf  
from datetime import date
from pandas_datareader import data as pdr
yf.pdr_override()

# deep learning libraries
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout

# fetch data for training
def SaveData(df, filename):
  df.to_csv(filename + '.csv')
today = date.today()
dataname='^NSEI'+'_'+str(today)
data=pdr.get_data_yahoo('^NSEI', start='2015-01-01', end=today)
SaveData(data, dataname)
data= pd.read_csv(dataname+'.csv')

# drop not required column
data.drop(columns=['Adj Close'], inplace=True)
data['Date'] = pd.to_datetime(data['Date'])

# 80% will be used for traning, and 20% for testing
train_size = 0.8       # 80%
split_index = int(train_size * data.shape[0])

factors_column = ['Open', 'High', 'Low', 'Close', 'Volume']
y_col_index = 3 # Close

train_set = data[factors_column].values[:split_index]
test_set = data[factors_column].values[split_index:]

# scale our price from 0 to 1
sc = MinMaxScaler(feature_range = (0, 1))
train_set_scaled = sc.fit_transform(train_set)
test_set_scaled = sc.fit_transform(test_set)

# Predicting Closing Price
# Generate windowed timestamp data
# this function will combine data of 20 days (we can change it using time_window parameter) 
time_window =  28     # 28 days
days_step =1         # skip 1 days in between, can be set to 1 day
def generate_data(series, time_window=4, days_step=1):
  X = []
  y = []
  for i in range(28, len(series)):
    X.append(series[i-time_window: i: days_step])
    y.append(series[i])                                 # <---- only changed this, insetead of taking only closing price, every column value is used
  return (np.array(X), np.array(y))

X_train, y_train = generate_data(train_set_scaled, time_window, days_step)
X_test, y_test = generate_data(test_set_scaled, time_window, days_step)

model = Sequential()

# layer 1
model.add(LSTM(units = 64, return_sequences = True, input_shape = X_train.shape[1:]))
model.add(Dropout(0.2))

# layer 2
model.add(LSTM(units = 32, return_sequences = True))
model.add(Dropout(0.2))

# layer 3
model.add(LSTM(units = 16, return_sequences = True))
model.add(Dropout(0.2))

# layer 4
model.add(LSTM(units = 8, return_sequences = True))
model.add(Dropout(0.2))

# layer 4
model.add(LSTM(units = 5))

# Compile and train LSTM Network
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = model.fit(X_train,
                    y_train,
                    epochs = 1000,
                    batch_size = 64,
                    validation_data = (X_test, y_test))

## future forecasting
def predict_n_days(df, n=30, step=0.1):
    for i in range(n):
        X = df[factors_column].values[df.shape[0]-time_window::step]
        X = sc.transform(X)
        y = model.predict(np.expand_dims(X, axis=0))
        y = sc.inverse_transform(y)[0]

        next_day_prediction = { key: value for key, value in zip(factors_column, y)}
        next_day_prediction['Date'] = df.iloc[-1].Date + pd.Timedelta(days=1)
        
        df = df.append(next_day_prediction, ignore_index=True)
    return df

days= 5    
#days_step =0.1   
predicted_df = predict_n_days(data,days,days_step)

fig = plt.figure(figsize = (25, 7))
#plt.plot(data.Date, data.Close, 'r-', label = 'Option Close')
plt.plot(predicted_df.Date.values[-days: ], predicted_df.Close[-days:], 'b--', label = 'Future Prediction')

plt.title('Nifty50 Forecasting')
plt.xlabel('Date')
plt.ylabel('Nifty50')
plt.legend()
plt.show()
# Out:
# WARNING: You are using pip version 21.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: yfinance in c:\python\python39\lib\site-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in c:\python\python39\lib\site-packages (from yfinance) (1.3.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\python\python39\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.26 in c:\python\python39\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in c:\python\python39\lib\site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: numpy>=1.15 in c:\python\python39\lib\site-packages (from yfinance) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python\python39\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\python\python39\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python39\lib\site-packages (from requests>=2.26->yfinance) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python39\lib\site-packages (from requests>=2.26->yfinance) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\python39\lib\site-packages (from requests>=2.26->yfinance) (1.25.11)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python\python39\lib\site-packages (from requests>=2.26->yfinance) (2.0.6)
# Requirement already satisfied: six>=1.5 in c:\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/1000
# 25/25 [==============================] - 24s 374ms/step - loss: 0.0890 - val_loss: 0.1294
# Epoch 2/1000
# 25/25 [==============================] - 3s 111ms/step - loss: 0.0374 - val_loss: 0.0809
# Epoch 3/1000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0238 - val_loss: 0.0548
# Epoch 4/1000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0162 - val_loss: 0.0402
# Epoch 5/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0116 - val_loss: 0.0325
# Epoch 6/1000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0089 - val_loss: 0.0292
# Epoch 7/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0070 - val_loss: 0.0255
# Epoch 8/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0059 - val_loss: 0.0261
# Epoch 9/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0052 - val_loss: 0.0252
# Epoch 10/1000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0045 - val_loss: 0.0262
# Epoch 11/1000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0041 - val_loss: 0.0244
# Epoch 12/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0036 - val_loss: 0.0267
# Epoch 13/1000
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0036 - val_loss: 0.0244
# Epoch 14/1000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.0034 - val_loss: 0.0242
# Epoch 15/1000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0032 - val_loss: 0.0235
# Epoch 16/1000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.0032 - val_loss: 0.0211
# Epoch 17/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0030 - val_loss: 0.0247
# Epoch 18/1000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0030 - val_loss: 0.0218
# Epoch 19/1000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0029 - val_loss: 0.0217
# Epoch 20/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0028 - val_loss: 0.0237
# Epoch 21/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0028 - val_loss: 0.0232
# Epoch 22/1000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0027 - val_loss: 0.0198
# Epoch 23/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0027 - val_loss: 0.0201
# Epoch 24/1000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0026 - val_loss: 0.0208
# Epoch 25/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0025 - val_loss: 0.0222
# Epoch 26/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0026 - val_loss: 0.0208
# Epoch 27/1000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0025 - val_loss: 0.0212
# Epoch 28/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0023 - val_loss: 0.0212
# Epoch 29/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0024 - val_loss: 0.0223
# Epoch 30/1000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0024 - val_loss: 0.0197
# Epoch 31/1000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0022 - val_loss: 0.0206
# Epoch 32/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0022 - val_loss: 0.0204
# Epoch 33/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0022 - val_loss: 0.0193
# Epoch 34/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0022 - val_loss: 0.0200
# Epoch 35/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0022 - val_loss: 0.0187
# Epoch 36/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0022 - val_loss: 0.0185
# Epoch 37/1000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0022 - val_loss: 0.0183
# Epoch 38/1000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0021 - val_loss: 0.0184
# Epoch 39/1000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0020 - val_loss: 0.0179
# Epoch 40/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0021 - val_loss: 0.0191
# Epoch 41/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0021 - val_loss: 0.0187
# Epoch 42/1000
# 25/25 [==============================] - 3s 105ms/step - loss: 0.0021 - val_loss: 0.0210
# Epoch 43/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0021 - val_loss: 0.0189
# Epoch 44/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0021 - val_loss: 0.0180
# Epoch 45/1000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0020 - val_loss: 0.0179
# Epoch 46/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0020 - val_loss: 0.0176
# Epoch 47/1000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0020 - val_loss: 0.0187
# Epoch 48/1000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.0019 - val_loss: 0.0184
# Epoch 49/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0020 - val_loss: 0.0183
# Epoch 50/1000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0020 - val_loss: 0.0175
# Epoch 51/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0020 - val_loss: 0.0173
# Epoch 52/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0019 - val_loss: 0.0185
# Epoch 53/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0019 - val_loss: 0.0168
# Epoch 54/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0019 - val_loss: 0.0193
# Epoch 55/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0019 - val_loss: 0.0178
# Epoch 56/1000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0018 - val_loss: 0.0165
# Epoch 57/1000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0019 - val_loss: 0.0169
# Epoch 58/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0018 - val_loss: 0.0181
# Epoch 59/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0018 - val_loss: 0.0191
# Epoch 60/1000
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0018 - val_loss: 0.0166
# Epoch 61/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0019 - val_loss: 0.0159
# Epoch 62/1000
# 25/25 [==============================] - 2s 88ms/step - loss: 0.0018 - val_loss: 0.0173
# Epoch 63/1000
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0018 - val_loss: 0.0177
# Epoch 64/1000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0018 - val_loss: 0.0179
# Epoch 65/1000
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0017 - val_loss: 0.0179
# Epoch 66/1000
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0017 - val_loss: 0.0159
# Epoch 67/1000
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0018 - val_loss: 0.0184
# Epoch 68/1000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0017 - val_loss: 0.0160
# Epoch 69/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0017 - val_loss: 0.0173
# Epoch 70/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0017 - val_loss: 0.0171
# Epoch 71/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0017 - val_loss: 0.0164
# Epoch 72/1000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0018 - val_loss: 0.0179
# Epoch 73/1000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0017 - val_loss: 0.0169
# Epoch 74/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0017 - val_loss: 0.0174
# Epoch 75/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0017 - val_loss: 0.0169
# Epoch 76/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0017 - val_loss: 0.0163
# Epoch 77/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0016 - val_loss: 0.0168
# Epoch 78/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0016 - val_loss: 0.0161
# Epoch 79/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0016 - val_loss: 0.0176
# Epoch 80/1000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0016 - val_loss: 0.0153
# Epoch 81/1000
# 25/25 [==============================] - 3s 115ms/step - loss: 0.0016 - val_loss: 0.0159
# Epoch 82/1000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.0016 - val_loss: 0.0161
# Epoch 83/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0017 - val_loss: 0.0156
# Epoch 84/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0016 - val_loss: 0.0163
# Epoch 85/1000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.0016 - val_loss: 0.0156
# Epoch 86/1000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.0016 - val_loss: 0.0171
# Epoch 87/1000
# 25/25 [==============================] - 2s 101ms/step - loss: 0.0016 - val_loss: 0.0167
# Epoch 88/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0016 - val_loss: 0.0167
# Epoch 89/1000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.0016 - val_loss: 0.0145
# Epoch 90/1000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0016 - val_loss: 0.0163
# Epoch 91/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0015 - val_loss: 0.0160
# Epoch 92/1000
# 25/25 [==============================] - 3s 107ms/step - loss: 0.0016 - val_loss: 0.0154
# Epoch 93/1000
# 25/25 [==============================] - 2s 99ms/step - loss: 0.0016 - val_loss: 0.0150
# Epoch 94/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0016 - val_loss: 0.0153
# Epoch 95/1000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0016 - val_loss: 0.0167
# Epoch 96/1000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0016 - val_loss: 0.0150
# Epoch 97/1000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.0016 - val_loss: 0.0153
# Epoch 98/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0016 - val_loss: 0.0144
# Epoch 99/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0016 - val_loss: 0.0170
# Epoch 100/1000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0015 - val_loss: 0.0155
# Epoch 101/1000
# 25/25 [==============================] - 2s 95ms/step - loss: 0.0016 - val_loss: 0.0149
# Epoch 102/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0016 - val_loss: 0.0151
# Epoch 103/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0015 - val_loss: 0.0140
# Epoch 104/1000
# 25/25 [==============================] - 3s 100ms/step - loss: 0.0015 - val_loss: 0.0146
# Epoch 105/1000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0016 - val_loss: 0.0146
# Epoch 106/1000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0015 - val_loss: 0.0136
# Epoch 107/1000
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0015 - val_loss: 0.0159
# Epoch 108/1000
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0015 - val_loss: 0.0142
# Epoch 109/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0015 - val_loss: 0.0147
# Epoch 110/1000
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0015 - val_loss: 0.0154
# Epoch 111/1000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.0015 - val_loss: 0.0149
# Epoch 112/1000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0015 - val_loss: 0.0140
# Epoch 113/1000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.0015 - val_loss: 0.0165
# Epoch 114/1000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.0014 - val_loss: 0.0150
# Epoch 115/1000
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 116/1000
# 25/25 [==============================] - 3s 111ms/step - loss: 0.0015 - val_loss: 0.0135
# Epoch 117/1000
# 25/25 [==============================] - 3s 108ms/step - loss: 0.0015 - val_loss: 0.0142
# Epoch 118/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0015 - val_loss: 0.0138
# Epoch 119/1000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.0014 - val_loss: 0.0164
# Epoch 120/1000
# 25/25 [==============================] - 3s 110ms/step - loss: 0.0015 - val_loss: 0.0142
# Epoch 121/1000
# 25/25 [==============================] - 3s 107ms/step - loss: 0.0015 - val_loss: 0.0148
# Epoch 122/1000
# 25/25 [==============================] - 3s 105ms/step - loss: 0.0015 - val_loss: 0.0143
# Epoch 123/1000
# 25/25 [==============================] - 2s 98ms/step - loss: 0.0014 - val_loss: 0.0136
# Epoch 124/1000
# 25/25 [==============================] - 3s 101ms/step - loss: 0.0014 - val_loss: 0.0140
# Epoch 125/1000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 126/1000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 127/1000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 128/1000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.0014 - val_loss: 0.0135
# Epoch 129/1000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.0014 - val_loss: 0.0129
# Epoch 130/1000
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 131/1000
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0014 - val_loss: 0.0151
# Epoch 132/1000
# 25/25 [==============================] - 4s 182ms/step - loss: 0.0014 - val_loss: 0.0157
# Epoch 133/1000
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0014 - val_loss: 0.0156
# Epoch 134/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0014 - val_loss: 0.0149
# Epoch 135/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 136/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0014 - val_loss: 0.0143
# Epoch 137/1000
# 25/25 [==============================] - 3s 112ms/step - loss: 0.0014 - val_loss: 0.0148
# Epoch 138/1000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.0014 - val_loss: 0.0146
# Epoch 139/1000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.0014 - val_loss: 0.0142
# Epoch 140/1000
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0014 - val_loss: 0.0158
# Epoch 141/1000
# 25/25 [==============================] - 3s 115ms/step - loss: 0.0013 - val_loss: 0.0147
# Epoch 142/1000
# 25/25 [==============================] - 3s 106ms/step - loss: 0.0014 - val_loss: 0.0171
# Epoch 143/1000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.0014 - val_loss: 0.0159
# Epoch 144/1000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.0014 - val_loss: 0.0148
# Epoch 145/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0014 - val_loss: 0.0159
# Epoch 146/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0014 - val_loss: 0.0164
# Epoch 147/1000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.0014 - val_loss: 0.0147
# Epoch 148/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0013 - val_loss: 0.0144
# Epoch 149/1000
# 25/25 [==============================] - 4s 142ms/step - loss: 0.0013 - val_loss: 0.0162
# Epoch 150/1000
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0014 - val_loss: 0.0162
# Epoch 151/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0013 - val_loss: 0.0157
# Epoch 152/1000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.0013 - val_loss: 0.0150
# Epoch 153/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0013 - val_loss: 0.0154
# Epoch 154/1000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.0013 - val_loss: 0.0151
# Epoch 155/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0013 - val_loss: 0.0164
# Epoch 156/1000
# 25/25 [==============================] - 3s 128ms/step - loss: 0.0013 - val_loss: 0.0166
# Epoch 157/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0013 - val_loss: 0.0174
# Epoch 158/1000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.0013 - val_loss: 0.0153
# Epoch 159/1000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.0013 - val_loss: 0.0162
# Epoch 160/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0013 - val_loss: 0.0164
# Epoch 161/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0013 - val_loss: 0.0160
# Epoch 162/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0013 - val_loss: 0.0165
# Epoch 163/1000
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0013 - val_loss: 0.0171
# Epoch 164/1000
# 25/25 [==============================] - 4s 160ms/step - loss: 0.0013 - val_loss: 0.0162
# Epoch 165/1000
# 25/25 [==============================] - 4s 142ms/step - loss: 0.0013 - val_loss: 0.0161
# Epoch 166/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0013 - val_loss: 0.0175
# Epoch 167/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0013 - val_loss: 0.0173
# Epoch 168/1000
# 25/25 [==============================] - 3s 132ms/step - loss: 0.0012 - val_loss: 0.0163
# Epoch 169/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0013 - val_loss: 0.0192
# Epoch 170/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0013 - val_loss: 0.0179
# Epoch 171/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0013 - val_loss: 0.0169
# Epoch 172/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0014 - val_loss: 0.0168
# Epoch 173/1000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.0013 - val_loss: 0.0156
# Epoch 174/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 175/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0013 - val_loss: 0.0168
# Epoch 176/1000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.0013 - val_loss: 0.0179
# Epoch 177/1000
# 25/25 [==============================] - 3s 128ms/step - loss: 0.0013 - val_loss: 0.0166
# Epoch 178/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0013 - val_loss: 0.0160
# Epoch 179/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0012 - val_loss: 0.0175
# Epoch 180/1000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0013 - val_loss: 0.0168
# Epoch 181/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0012 - val_loss: 0.0171
# Epoch 182/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0013 - val_loss: 0.0179
# Epoch 183/1000
# 25/25 [==============================] - 3s 112ms/step - loss: 0.0013 - val_loss: 0.0176
# Epoch 184/1000
# 25/25 [==============================] - 3s 115ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 185/1000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.0012 - val_loss: 0.0171
# Epoch 186/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0013 - val_loss: 0.0178
# Epoch 187/1000
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0012 - val_loss: 0.0179
# Epoch 188/1000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 189/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0012 - val_loss: 0.0188
# Epoch 190/1000
# 25/25 [==============================] - 3s 113ms/step - loss: 0.0012 - val_loss: 0.0172
# Epoch 191/1000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.0012 - val_loss: 0.0190
# Epoch 192/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0012 - val_loss: 0.0186
# Epoch 193/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0012 - val_loss: 0.0178
# Epoch 194/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0013 - val_loss: 0.0171
# Epoch 195/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0012 - val_loss: 0.0177
# Epoch 196/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0012 - val_loss: 0.0182
# Epoch 197/1000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0012 - val_loss: 0.0168
# Epoch 198/1000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.0012 - val_loss: 0.0193
# Epoch 199/1000
# 25/25 [==============================] - 3s 115ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 200/1000
# 25/25 [==============================] - 3s 113ms/step - loss: 0.0012 - val_loss: 0.0181
# Epoch 201/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0012 - val_loss: 0.0178
# Epoch 202/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0012 - val_loss: 0.0191
# Epoch 203/1000
# 25/25 [==============================] - 3s 112ms/step - loss: 0.0012 - val_loss: 0.0187
# Epoch 204/1000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.0012 - val_loss: 0.0173
# Epoch 205/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0012 - val_loss: 0.0163
# Epoch 206/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 207/1000
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0012 - val_loss: 0.0182
# Epoch 208/1000
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0012 - val_loss: 0.0188
# Epoch 209/1000
# 25/25 [==============================] - 3s 107ms/step - loss: 0.0012 - val_loss: 0.0174
# Epoch 210/1000
# 25/25 [==============================] - 3s 104ms/step - loss: 0.0012 - val_loss: 0.0173
# Epoch 211/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0011 - val_loss: 0.0176
# Epoch 212/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0011 - val_loss: 0.0176
# Epoch 213/1000
# 25/25 [==============================] - 4s 155ms/step - loss: 0.0012 - val_loss: 0.0173
# Epoch 214/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 215/1000
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0011 - val_loss: 0.0177
# Epoch 216/1000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.0011 - val_loss: 0.0172
# Epoch 217/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 218/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0012 - val_loss: 0.0192
# Epoch 219/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 220/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0011 - val_loss: 0.0180
# Epoch 221/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0012 - val_loss: 0.0180
# Epoch 222/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0011 - val_loss: 0.0187
# Epoch 223/1000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.0012 - val_loss: 0.0173
# Epoch 224/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0012 - val_loss: 0.0187
# Epoch 225/1000
# 25/25 [==============================] - 3s 119ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 226/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0012 - val_loss: 0.0176
# Epoch 227/1000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.0011 - val_loss: 0.0168
# Epoch 228/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0012 - val_loss: 0.0161
# Epoch 229/1000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0011 - val_loss: 0.0182
# Epoch 230/1000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0012 - val_loss: 0.0171
# Epoch 231/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 0.0011 - val_loss: 0.0169
# Epoch 232/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0011 - val_loss: 0.0167
# Epoch 233/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0011 - val_loss: 0.0184
# Epoch 234/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0011 - val_loss: 0.0182
# Epoch 235/1000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0011 - val_loss: 0.0174
# Epoch 236/1000
# 25/25 [==============================] - 4s 142ms/step - loss: 0.0011 - val_loss: 0.0163
# Epoch 237/1000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.0012 - val_loss: 0.0177
# Epoch 238/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0011 - val_loss: 0.0181
# Epoch 239/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0011 - val_loss: 0.0166
# Epoch 240/1000
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0011 - val_loss: 0.0174
# Epoch 241/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0011 - val_loss: 0.0181
# Epoch 242/1000
# 25/25 [==============================] - 4s 142ms/step - loss: 0.0011 - val_loss: 0.0167
# Epoch 243/1000
# 25/25 [==============================] - 4s 141ms/step - loss: 0.0011 - val_loss: 0.0166
# Epoch 244/1000
# 25/25 [==============================] - 3s 141ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 245/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 0.0011 - val_loss: 0.0171
# Epoch 246/1000
# 25/25 [==============================] - 4s 146ms/step - loss: 0.0011 - val_loss: 0.0171
# Epoch 247/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0011 - val_loss: 0.0165
# Epoch 248/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0011 - val_loss: 0.0166
# Epoch 249/1000
# 25/25 [==============================] - 3s 132ms/step - loss: 0.0011 - val_loss: 0.0183
# Epoch 250/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0011 - val_loss: 0.0169
# Epoch 251/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0011 - val_loss: 0.0177
# Epoch 252/1000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.0011 - val_loss: 0.0174
# Epoch 253/1000
# 25/25 [==============================] - 3s 139ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 254/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0011 - val_loss: 0.0170
# Epoch 255/1000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.0011 - val_loss: 0.0170
# Epoch 256/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0011 - val_loss: 0.0151
# Epoch 257/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0011 - val_loss: 0.0156
# Epoch 258/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 259/1000
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0011 - val_loss: 0.0155
# Epoch 260/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0011 - val_loss: 0.0168
# Epoch 261/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 0.0011 - val_loss: 0.0166
# Epoch 262/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0011 - val_loss: 0.0160
# Epoch 263/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 264/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0011 - val_loss: 0.0173
# Epoch 265/1000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.0011 - val_loss: 0.0165
# Epoch 266/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 267/1000
# 25/25 [==============================] - 3s 133ms/step - loss: 0.0011 - val_loss: 0.0164
# Epoch 268/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 0.0010 - val_loss: 0.0153
# Epoch 269/1000
# 25/25 [==============================] - 3s 109ms/step - loss: 0.0010 - val_loss: 0.0142
# Epoch 270/1000
# 25/25 [==============================] - 3s 112ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 271/1000
# 25/25 [==============================] - 3s 115ms/step - loss: 0.0011 - val_loss: 0.0161
# Epoch 272/1000
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0011 - val_loss: 0.0151
# Epoch 273/1000
# 25/25 [==============================] - 3s 114ms/step - loss: 0.0010 - val_loss: 0.0165
# Epoch 274/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0010 - val_loss: 0.0168
# Epoch 275/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0011 - val_loss: 0.0163
# Epoch 276/1000
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0011 - val_loss: 0.0150
# Epoch 277/1000
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0010 - val_loss: 0.0156
# Epoch 278/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 279/1000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0010 - val_loss: 0.0158
# Epoch 280/1000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 281/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 9.9488e-04 - val_loss: 0.0143
# Epoch 282/1000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.0010 - val_loss: 0.0151
# Epoch 283/1000
# 25/25 [==============================] - 3s 130ms/step - loss: 9.7079e-04 - val_loss: 0.0154
# Epoch 284/1000
# 25/25 [==============================] - 3s 116ms/step - loss: 0.0010 - val_loss: 0.0176
# Epoch 285/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0010 - val_loss: 0.0169
# Epoch 286/1000
# 25/25 [==============================] - 3s 135ms/step - loss: 0.0011 - val_loss: 0.0143
# Epoch 287/1000
# 25/25 [==============================] - 3s 128ms/step - loss: 0.0010 - val_loss: 0.0157
# Epoch 288/1000
# 25/25 [==============================] - 3s 111ms/step - loss: 0.0010 - val_loss: 0.0158
# Epoch 289/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 9.8741e-04 - val_loss: 0.0163
# Epoch 290/1000
# 25/25 [==============================] - 3s 139ms/step - loss: 0.0010 - val_loss: 0.0160
# Epoch 291/1000
# 25/25 [==============================] - 3s 136ms/step - loss: 0.0010 - val_loss: 0.0166
# Epoch 292/1000
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0011 - val_loss: 0.0143
# Epoch 293/1000
# 25/25 [==============================] - 4s 160ms/step - loss: 0.0010 - val_loss: 0.0161
# Epoch 294/1000
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0010 - val_loss: 0.0148
# Epoch 295/1000
# 25/25 [==============================] - 3s 125ms/step - loss: 9.7756e-04 - val_loss: 0.0159
# Epoch 296/1000
# 25/25 [==============================] - 3s 115ms/step - loss: 9.9121e-04 - val_loss: 0.0157
# Epoch 297/1000
# 25/25 [==============================] - 3s 118ms/step - loss: 0.0010 - val_loss: 0.0146
# Epoch 298/1000
# 25/25 [==============================] - 3s 117ms/step - loss: 9.6784e-04 - val_loss: 0.0155
# Epoch 299/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 9.8536e-04 - val_loss: 0.0151
# Epoch 300/1000
# 25/25 [==============================] - 3s 122ms/step - loss:
1000
# 25/25 [==============================] - 4s 142ms/step - loss: 8.7951e-04 - val_loss: 0.0153
# Epoch 388/1000
# 25/25 [==============================] - 3s 136ms/step - loss: 8.9523e-04 - val_loss: 0.0167
# Epoch 389/1000
# 25/25 [==============================] - 4s 160ms/step - loss: 9.2056e-04 - val_loss: 0.0153
# Epoch 390/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 8.7779e-04 - val_loss: 0.0164
# Epoch 391/1000
# 25/25 [==============================] - 4s 144ms/step - loss: 9.3460e-04 - val_loss: 0.0160
# Epoch 392/1000
# 25/25 [==============================] - 4s 150ms/step - loss: 8.8638e-04 - val_loss: 0.0157
# Epoch 393/1000
# 25/25 [==============================] - 4s 155ms/step - loss: 8.8099e-04 - val_loss: 0.0177
# Epoch 394/1000
# 25/25 [==============================] - 4s 164ms/step - loss: 8.5473e-04 - val_loss: 0.0167
# Epoch 395/1000
# 25/25 [==============================] - 4s 159ms/step - loss: 8.8670e-04 - val_loss: 0.0172
# Epoch 396/1000
# 25/25 [==============================] - 4s 162ms/step - loss: 8.9455e-04 - val_loss: 0.0166
# Epoch 397/1000
# 25/25 [==============================] - 4s 156ms/step - loss: 9.2702e-04 - val_loss: 0.0183
# Epoch 398/1000
# 25/25 [==============================] - 4s 154ms/step - loss: 9.0607e-04 - val_loss: 0.0156
# Epoch 399/1000
# 25/25 [==============================] - 4s 161ms/step - loss: 8.5698e-04 - val_loss: 0.0152
# Epoch 400/1000
# 25/25 [==============================] - 3s 133ms/step - loss: 8.4519e-04 - val_loss: 0.0157
# Epoch 401/1000
# 25/25 [==============================] - 4s 164ms/step - loss: 8.4139e-04 - val_loss: 0.0157
# Epoch 402/1000
# 25/25 [==============================] - 4s 160ms/step - loss: 8.6751e-04 - val_loss: 0.0168
# Epoch 403/1000
# 25/25 [==============================] - 4s 153ms/step - loss: 8.7226e-04 - val_loss: 0.0155
# Epoch 404/1000
# 25/25 [==============================] - 4s 174ms/step - loss: 8.4565e-04 - val_loss: 0.0154
# Epoch 405/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 8.1562e-04 - val_loss: 0.0162
# Epoch 406/1000
# 25/25 [==============================] - 3s 135ms/step - loss: 8.8268e-04 - val_loss: 0.0153
# Epoch 407/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 8.6496e-04 - val_loss: 0.0159
# Epoch 408/1000
# 25/25 [==============================] - 3s 128ms/step - loss: 8.7329e-04 - val_loss: 0.0167
# Epoch 409/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 8.6268e-04 - val_loss: 0.0165
# Epoch 410/1000
# 25/25 [==============================] - 4s 161ms/step - loss: 8.6124e-04 - val_loss: 0.0156
# Epoch 411/1000
# 25/25 [==============================] - 4s 172ms/step - loss: 8.4250e-04 - val_loss: 0.0158
# Epoch 412/1000
# 25/25 [==============================] - 4s 151ms/step - loss: 8.6451e-04 - val_loss: 0.0168
# Epoch 413/1000
# 25/25 [==============================] - 4s 165ms/step - loss: 8.4816e-04 - val_loss: 0.0167
# Epoch 414/1000
# 25/25 [==============================] - 5s 204ms/step - loss: 8.3762e-04 - val_loss: 0.0159
# Epoch 415/1000
# 25/25 [==============================] - 4s 169ms/step - loss: 8.4434e-04 - val_loss: 0.0165
# Epoch 416/1000
# 25/25 [==============================] - 4s 168ms/step - loss: 8.7538e-04 - val_loss: 0.0165
# Epoch 417/1000
# 25/25 [==============================] - 5s 194ms/step - loss: 8.8286e-04 - val_loss: 0.0165
# Epoch 418/1000
# 25/25 [==============================] - 5s 186ms/step - loss: 8.6371e-04 - val_loss: 0.0157
# Epoch 419/1000
# 25/25 [==============================] - 4s 175ms/step - loss: 8.6001e-04 - val_loss: 0.0154
# Epoch 420/1000
# 25/25 [==============================] - 4s 157ms/step - loss: 8.6378e-04 - val_loss: 0.0149
# Epoch 421/1000
# 25/25 [==============================] - 4s 162ms/step - loss: 8.4905e-04 - val_loss: 0.0151
# Epoch 422/1000
# 25/25 [==============================] - 3s 133ms/step - loss: 8.6732e-04 - val_loss: 0.0158
# Epoch 423/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 8.9582e-04 - val_loss: 0.0155
# Epoch 424/1000
# 25/25 [==============================] - 5s 190ms/step - loss: 8.6774e-04 - val_loss: 0.0163
# Epoch 425/1000
# 25/25 [==============================] - 5s 186ms/step - loss: 8.2148e-04 - val_loss: 0.0158
# Epoch 426/1000
# 25/25 [==============================] - 5s 188ms/step - loss: 8.6078e-04 - val_loss: 0.0167
# Epoch 427/1000
# 25/25 [==============================] - 4s 161ms/step - loss: 8.5753e-04 - val_loss: 0.0163
# Epoch 428/1000
# 25/25 [==============================] - 4s 159ms/step - loss: 8.4515e-04 - val_loss: 0.0160
# Epoch 429/1000
# 25/25 [==============================] - 4s 145ms/step - loss: 8.6332e-04 - val_loss: 0.0162
# Epoch 430/1000
# 25/25 [==============================] - 4s 142ms/step - loss: 8.8066e-04 - val_loss: 0.0167
# Epoch 431/1000
# 25/25 [==============================] - 3s 129ms/step - loss: 8.8183e-04 - val_loss: 0.0156
# Epoch 432/1000
# 25/25 [==============================] - 3s 123ms/step - loss: 8.2619e-04 - val_loss: 0.0156
# Epoch 433/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 8.9073e-04 - val_loss: 0.0157
# Epoch 434/1000
# 25/25 [==============================] - 4s 153ms/step - loss: 8.6551e-04 - val_loss: 0.0153
# Epoch 435/1000
# 25/25 [==============================] - 4s 145ms/step - loss: 8.4630e-04 - val_loss: 0.0153
# Epoch 436/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 8.5701e-04 - val_loss: 0.0164
# Epoch 437/1000
# 25/25 [==============================] - 4s 168ms/step - loss: 8.5537e-04 - val_loss: 0.0160
# Epoch 438/1000
# 25/25 [==============================] - 4s 163ms/step - loss: 8.8023e-04 - val_loss: 0.0166
# Epoch 439/1000
# 25/25 [==============================] - 4s 142ms/step - loss: 8.3840e-04 - val_loss: 0.0160
# Epoch 440/1000
# 25/25 [==============================] - 4s 147ms/step - loss: 8.1131e-04 - val_loss: 0.0155
# Epoch 441/1000
# ...
# Epoch 449/1000
# 25/25 [==============================] - 3s 126ms/step - loss: 8.0319e-04 - val_loss: 0.0156
# Epoch 450/1000
# 25/25 [==============================] - 3s 127ms/step - loss: 8.2098e-04 - val_loss: 0.0153
# Epoch 451/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 8.0293e-04 - val_loss: 0.0164
# Epoch 452/1000
# 25/25 [==============================] - 3s 128ms/step - loss: 8.5256e-04 - val_loss: 0.0156
# Epoch 453/1000
# 25/25 [==============================] - 4s 156ms/step - loss: 8.2845e-04 - val_loss: 0.0156
# Epoch 454/1000
# 25/25 [==============================] - 5s 186ms/step - loss: 7.8254e-04 - val_loss: 0.0159
# Epoch 455/1000
# 25/25 [==============================] - 4s 172ms/step - loss: 8.0355e-04 - val_loss: 0.0151
# Epoch 456/1000
# 25/25 [==============================] - 4s 176ms/step - loss: 8.3038e-04 - val_loss: 0.0154
# Epoch 457/1000
# 25/25 [==============================] - 3s 135ms/step - loss: 8.2265e-04 - val_loss: 0.0160
# Epoch 458/1000
1000
# 25/25 [==============================] - 3s 121ms/step - loss: 8.0678e-04 - val_loss: 0.0154
# Epoch 518/1000
# 25/25 [==============================] - 3s 131ms/step - loss: 7.6826e-04 - val_loss: 0.0152
# Epoch 519/1000
# 25/25 [==============================] - 3s 114ms/step - loss: 7.4911e-04 - val_loss: 0.0167
# Epoch 520/1000
# 25/25 [==============================] - 3s 131ms/step - loss: 7.4557e-04 - val_loss: 0.0162
# Epoch 521/1000
# 25/25 [==============================] - 3s 119ms/step - loss: 7.6002e-04 - val_loss: 0.0157
# Epoch 522/1000
# 25/25 [==============================] - 4s 149ms/step - loss: 8.4044e-04 - val_loss: 0.0162
# Epoch 523/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 8.0155e-04 - val_loss: 0.0142
# Epoch 524/1000
# 25/25 [==============================] - 4s 153ms/step - loss: 7.6368e-04 - val_loss: 0.0160
# Epoch 525/1000
# 25/25 [==============================] - 3s 138ms/step - loss: 8.1024e-04 - val_loss: 0.0156
# Epoch 526/1000
# 25/25 [==============================] - 3s 139ms/step - loss: 7.6185e-04 - val_loss: 0.0159
# Epoch 527/1000
# 25/25 [==============================] - 4s 147ms/step - loss: 7.6086e-04 - val_loss: 0.0152
# Epoch 528/1000
# 25/25 [==============================] - 3s 141ms/step - loss: 7.8421e-04 - val_loss: 0.0150
# Epoch 529/1000
# 25/25 [==============================] - 3s 122ms/step - loss: 7.6779e-04 - val_loss: 0.0158
# Epoch 530/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 7.9991e-04 - val_loss: 0.0156
# Epoch 531/1000
# 25/25 [==============================] - 4s 143ms/step - loss: 7.8939e-04 - val_loss: 0.0155
# Epoch 532/1000
# 25/25 [==============================] - 3s 134ms/step - loss: 7.6616e-04 - val_loss: 0.0155
# Epoch 533/1000
# 25/25 [==============================] - 4s 144ms/step - loss: 8.3839e-04 - val_loss: 0.0155
# Epoch 534/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 7.9068e-04 - val_loss: 0.0152
# Epoch 535/1000
# 25/25 [==============================] - 4s 141ms/step - loss: 7.3776e-04 - val_loss: 0.0159
# Epoch 536/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 7.9142e-04 - val_loss: 0.0155
# Epoch 537/1000
# 25/25 [==============================] - 3s 137ms/step - loss: 7.9712e-04 - val_loss: 0.0152
# Epoch 538/1000
# 25/25 [==============================] - 3s 136ms/step - loss: 7.6607e-04 - val_loss: 0.0151
# Epoch 539/1000
# 25/25 [==============================] - 4s 143ms/step - loss: 7.8229e-04 - val_loss: 0.0149
# Epoch 540/1000
# 25/25 [==============================] - 4s 147ms/step - loss: 7.5340e-04 - val_loss: 0.0155
# Epoch 541/1000
# 25/25 [==============================] - 4s 145ms/step - loss: 7.4370e-04 - val_loss: 0.0161
# Epoch 542/1000
# 25/25 [==============================] - 3s 121ms/step - loss: 7.6102e-04 - val_loss: 0.0165
# Epoch 543/1000
# 25/25 [==============================] - 3s 116ms/step - loss: 7.4553e-04 - val_loss: 0.0156
# Epoch 544/1000
# 25/25 [==============================] - 4s 153ms/step - loss: 7.3084e-04 - val_loss: 0.0160
# Epoch 545/1000
# 25/25 [==============================] - 3s 132ms/step - loss: 7.6616e-04 - val_loss: 0.0155
# Epoch 546/1000
# 25/25 [==============================] - 3s 140ms/step - loss: 7.3884e-04 - val_loss: 0.0157
# Epoch 547/1000
# 25/25 [==============================] - 4s 149ms/step - loss: 7.2868e-04 - val_loss: 0.0157
# Epoch 548/1000
# 25/25 [==============================] - 4s 149ms/step - loss: 7.7300e-04 - val_loss: 0.0152
# Epoch 549/1000
# 25/25 [==============================] - 3s 130ms/step - loss: 7.5480e-04 - val_loss: 0.0151
# Epoch 550/1000
# 25/25 [==============================] - 3s 132ms/step - loss: 8.0618e-04 - val_loss: 0.0163
# Epoch 551/1000
# 25/25 [==============================] - 4s 145ms/step - loss: 8.1656e-04 - val_loss: 0.0154
# Epoch 552/1000
# 25/25 [==============================] - 4s 154ms/step - loss: 7.3372e-04 - val_loss: 0.0158
# Epoch 553/1000
# 25/25 [==============================] - 4s 160ms/step - loss: 7.9983e-04 - val_loss: 0.0159
# Epoch 554/1000
# 25/25 [==============================] - 4s 174ms/step - loss: 7.3665e-04 - val_loss: 0.0154
# Epoch 555/1000
# 25/25 [==============================] - 7s 290ms/step - loss: 7.5791e-04 - val_loss: 0.0155
# Epoch 556/1000
# 25/25 [==============================] - 6s 252ms/step - loss: 7.4618e-04 - val_loss: 0.0154
# Epoch 557/1000
# 25/25 [==============================] - 6s 240ms/step - loss: 7.1673e-04 - val_loss: 0.0161
# Epoch 558/1000
# 11/25 [============>.................] - ETA: 3s - loss: 7.1779e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14308/3454882415.py in <module>
#      83 # Compile and train LSTM Network
#      84 model.compile(optimizer = 'adam', loss = 'mean_squared_error')
# ---> 85 history = model.fit(X_train,
#      86                     y_train,
#      87                     epochs = 1000,
#
# c:\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Python\Python39\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# c:\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# c:\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# c:\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# MLP for OTP model Serialize to JSON and HDF5
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
import numpy
import os

# serialize model to JSON
model_json = model.to_json()
with open("model_5_28.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model_5_28.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# later...
 
# load json and create model
json_file = open('model_5_28.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model_5_28.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(X_train,
                    y_train, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# accuracy: 70.77%

# %%
def predict2_n_days(df, n=28, step=0.1):
    for i in range(n):
        X = df[factors_column].values[df.shape[0]-time_window::step]
        X = sc.transform(X)
        y = loaded_model.predict(np.expand_dims(X, axis=0))
        y = sc.inverse_transform(y)[0]

        next_day_prediction = { key: value for key, value in zip(factors_column, y)}
        next_day_prediction['Date'] = df.iloc[-1].Date + pd.Timedelta(days=1)
        
        df = df.append(next_day_prediction, ignore_index=True)
    return df

# %%
days= 5    
#days_step =0.1   
predicted_df = predict2_n_days(data,days,days_step)
fig = plt.figure(figsize = (25, 7))
#plt.plot(data.Date[-50:], data.Close[-50:], 'r-', label = 'Option Close')
plt.plot(predicted_df.Date.values[-days: ], predicted_df.Close[-days:], 'b--', label = 'Future Prediction')

plt.title('NIFTY50 Prediction')
plt.xlabel('Date')
plt.ylabel('NIFTY50')
plt.legend()
plt.show()

# %%
test_prediction = loaded_model.predict(X_test)
test_prediction = sc.inverse_transform(test_prediction)
fig = plt.figure(figsize = (15, 5))
plt.plot(data.Date.values[ split_index+28 : ], data.Close.values[ split_index+28: ], 'r-', label = 'Actual NIFTY50')
plt.plot(data['Date'].values[split_index+28 : ], test_prediction[:,3], 'b--', label = 'Prediction')

plt.title('NIFTY50 Prediction')
plt.xlabel('Date')
plt.ylabel('NIFTY50')
plt.legend()
plt.show()

# %%
plt.plot(range(len(history.history['loss'])),history.history['loss'], label='loss')
plt.plot(range(len(history.history['val_loss'])),history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
